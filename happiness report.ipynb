# %%
import numpy as np 
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error     Economy  \
# count      158.000000       158.000000      158.000000  158.000000
# mean        79.493671         5.375734        0.047885    0.846137
# std         45.754363         1.145010        0.017146    0.403121
# min          1.000000         2.839000        0.018480    0.000000
# 25%         40.250000         4.526000        0.037268    0.545808
# 50%         79.500000         5.232500        0.043940    0.910245
# 75%        118.750000         6.243750        0.052300    1.158448
# max        158.000000         7.587000        0.136930    1.690420
#
#            Family      Health     Freedom  Absence of Corruption  Generosity  \
# count  158.000000  158.000000  158.000000             158.000000  158.000000
# mean     0.991046    0.630259    0.428615               0.143422    0.237296
# std      0.272369    0.247078    0.150693               0.120034    0.126685
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy', 'Family', 'Health', 'Freedom',
#        'Absence of Corruption', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df = df.rename(columns={'Economy (GDP per Capita)':'Economy',
                                        'Health (Life Expectancy)':'Health',
                                        'Trust (Government Corruption)':'Absence of Corruption'})
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy   Family   Health  Freedom  \
# 0              7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# ...

# %%
col_names = df.columns.to_list()
col_names
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy',
#  'Family',
#  'Health',
#  'Freedom',
#  'Absence of Corruption',
#  'Generosity',
#  'Dystopia Residual']

# %%
col_to_float = col_names[3:10]
col_to_float
# Out:
# ['Happiness Score',
#  'Standard Error',
#  'Economy',
#  'Family',
#  'Health',
#  'Freedom',
#  'Absence of Corruption']

# %%
def replace_comma(df, col_name):
    for idx in range(len(df[col_name])):
        df[col_name][idx] = df[col_name][idx].replace(",", ".")
        
    return df[col_name]

# %%
for col_name in col_to_float:
    df[col_name] = df[col_name].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                158 non-null    object
#  1   Region                 158 non-null    object
#  2   Happiness Rank         158 non-null    int64
#  3   Happiness Score        158 non-null    float64
#  4   Standard Error         158 non-null    float64
#  5   Economy                158 non-null    float64
#  6   Family                 158 non-null    float64
#  7   Health                 158 non-null    float64
#  8   Freedom                158 non-null    float64
#  9   Absence of Corruption  158 non-null    float64
#  10  Generosity             158 non-null    float64
#  11  Dystopia Residual      158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df_new = df.drop(["Country","Happiness Rank"],axis=1)

# %%
plt.figure(figsize=(10,6))
df_happiest = df.sort_values(by="Happiness Score",ascending=False).iloc[0:10,:]
sns.barplot(x="Country",y="Happiness Score",data=df_happiest)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
plt.figure(figsize=(12,6))
df_happiest = df.sort_values(by="Happiness Score",ascending=True).iloc[0:10,:]
sns.barplot(x="Country",y="Happiness Score",data=df_happiest)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
sns.distplot(df_new["Standard Error"])
# Out:
# C:\Users\MohitLewis\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
df_new.columns
# Out:
# Index(['Region', 'Happiness Score', 'Standard Error', 'Economy', 'Family',
#        'Health', 'Freedom', 'Absence of Corruption', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
f1, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.histplot(df["Happiness Score"], color="purple",ax = axes)
plt.title("Histogram of Happiness Score")
# Out:
# Text(0.5, 1.0, 'Histogram of Happiness Score')

# %%
f2, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.histplot(df["Economy"], color="orange",ax = axes)
plt.title("Histogram of Economy")
# Out:
# Text(0.5, 1.0, 'Histogram of Economy')

# %%
f3, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.histplot(df["Family"], color="red",ax = axes)
plt.title("Histogram of Social Support")
# Out:
# Text(0.5, 1.0, 'Histogram of Social Support')

# %%
f4, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.histplot(df["Freedom"], color="blue",ax = axes)
plt.title("Histogram of Freedom")
# Out:
# Text(0.5, 1.0, 'Histogram of Freedom')

# %%
f5, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.histplot(df["Absence of Corruption"], color="pink",ax = axes)
plt.title("Histogram of Absence of Corruption")
# Out:
# Text(0.5, 1.0, 'Histogram of Absence of Corruption')

# %%
f6, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.histplot(df["Health"], color="green",ax = axes)
plt.title("Histogram of Health")
# Out:
# Text(0.5, 1.0, 'Histogram of Health')

# %%
f7, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.countplot(df["Region"])
plt.title("Countplot of Region")
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\MohitLewis\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f8, axes = plt.subplots(1,1, figsize = (10, 10))
g1 = sns.boxplot(data = df.loc[:, "Happiness Score"], orient = "v")
plt.title("Boxplot of Happiness Score")
plt.show()

# %%
f9, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.boxplot(data = df.loc[:, col_names[4:-1]], orient = "v", palette = "Set1")
plt.title("Boxplot of Factors")
plt.show()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_new["Region"] = le.fit_transform(df_new["Region"])

# %%
X = df_new.drop("Happiness Score",axis=1)
y = df["Happiness Score"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_scaled,y)
reg.score(X_scaled,y)
# Out:
# 0.999999943060637

# %%
# Correlation heatmap of features
f10, axes = plt.subplots(1,1, figsize = (16, 5))
sns.heatmap(df.corr(), annot = True, fmt = ".2f", linewidth = .7)
plt.title("Correlation between Features")
plt.show()
